# %% [markdown]
# <a href="https://colab.research.google.com/github/jpdeleon/chronos/blob/master/notebooks/examples-tois.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install git+https://github.com/jpdeleon/chronos.git@master

# %%
import chronos as cr
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %% [raw]
# tois_gaia = cr.query_gaia_params_of_all_tois(clobber=False, update=False)
# tois_gaia.head()

# %%
tois = cr.get_tois()
tois.head()
# Out:
#       TIC ID     TOI Previous CTOI  Master  SG1A  SG1B  SG2  SG3  SG4  SG5  \
# 0  231663901  101.01           NaN       5     5     5    5    5    5    5
# 1  149603524  102.01           NaN       5     5     5    5    5    5    5
# 2  336732616  103.01           NaN       5     5     5    5    5    5    5
# 3  231670397  104.01           NaN       5     5     5    5    5    5    5
# 4  144065872  105.01           NaN       5     5     5    5    5    5    5
#
#    ...  Stellar log(g) (cm/s^2) err Stellar Radius (R_Sun)  \
# 0  ...                          NaN                   0.86
# 1  ...                          NaN                   1.28
# 2  ...                          NaN                   1.40
# 3  ...                          NaN                   2.07
# 4  ...                          NaN                   1.13
#
#   Stellar Radius (R_Sun) err  Stellar Metallicity   Stellar Metallicity err  \
# 0                        NaN                  NaN                       NaN
# ...

# %%
import panel as pn
import hvplot.pandas

x = pn.widgets.Select(name='x', options=tois.columns.tolist())
y = pn.widgets.Select(name='y', options=tois.columns.tolist())
kind = pn.widgets.Select(name='kind', value='scatter', options=['bivariate', 'scatter'])

fields={'x': {'default': 'Period (days)'},
        'y': {'default': 'Planet Radius (R_Earth)'}
       }
plot = tois.hvplot(x=x, y=y, kind=kind, fields=fields, colorbar=False, width=600)
pn.Row(pn.WidgetBox(x, y, kind), plot)
# Out:
# Row
#     [0] WidgetBox
#         [0] Select(name='x', options=['TIC ID', 'TOI', ...], value='TIC ID')
#         [1] Select(name='y', options=['TIC ID', 'TOI', ...], value='TIC ID')
#         [2] Select(name='kind', options=['bivariate', 'scatter'], value='scatter')
#     [1] ParamFunction(function)
