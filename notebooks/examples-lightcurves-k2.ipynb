# %% [markdown]
# # K2 lightcurves

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as pl
import matplotlib
matplotlib.rcParams['font.size'] = 12

import chronos as cr
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %% [markdown]
# ## sap & pdcsap

# %%
epicid=211916756 #k2-95
campaign=5
star = cr.K2(epicid=epicid, campaign=campaign)
lc = star.get_lc()
lc.scatter()
# Out:
# Searching lightcurvefile for EPIC 211916756 (campaign 5)
# Found 1 lightcurves

# %% [markdown]
# ## everest

# %%
eve = cr.Everest(epicid=epicid, campaign=campaign, verbose=False)
eve.lc_everest.scatter()

# %% [markdown]
# ## K2SFF

# %%
k2sff = cr.K2sff(epicid=epicid, campaign=campaign, verbose=False)
k2sff.lc_k2sff.scatter()

# %% [markdown]
# ## Quick look

# %% [raw]
# fig = cr.make_kql(toiid=837);
