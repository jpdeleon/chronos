# %% [markdown]
# <a href="https://colab.research.google.com/github/jpdeleon/chronos/blob/master/notebooks/examples-lightcurves-k2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install git+https://github.com/jpdeleon/chronos.git@master

# %% [markdown]
# # K2 lightcurves

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as pl

import chronos as cr
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443

# %% [markdown]
# ## sap & pdcsap

# %%
epicid=247047380
campaign=13
star = cr.K2(epicid=epicid, campaign=campaign)
lc = star.get_lc(lctype="pdcsap")
lc.scatter()
# Out:
# Target: EPIC 247047380
# Searching lightcurvefile for EPIC 247047380 (campaign 13)
# Found 1 lightcurves

# %% [markdown]
# ## EVEREST

# %%
eve = cr.Everest(epicid=epicid, campaign=campaign, verbose=False)
lc = eve.lc_everest
lc.scatter()

# %%
eve.everest_recarray
# Out:
# FITS_rec([(140878., 82055.36297035, 85172.63633919, 10.01441278,   524288, 2987.58120445, 84982.70377511, 1., 10.11916328, 4.84761119, 1.84143035, -2.04599249, -4.72922866),
#           (140879., 82312.69950867, 82374.01841736,  9.92188983,        0, 2987.60163675, 85236.01899314, 1., 10.10926951, 4.82260346, 1.79823302, -2.02869744, -4.69144745),
#           (140880., 82203.85466576, 81462.55226707,  9.88881714,        0, 2987.62206885, 85123.15121358, 1., 10.09937175, 4.79766625, 1.75530251, -2.0114655 , -4.65381021),
#           ...,
#           (144819., 65306.24861711, 67442.42428207, 10.02919699,        0, 3068.10268294, 70075.47385738, 1., -5.56067234, 1.27979825, 2.14909014, -0.30181388, -2.16874939),
#           (144820., 69524.23478365, 72616.51333809, 10.1970906 , 16777216, 3068.12311473, 74295.81562331, 1., -5.56509054, 1.27943688, 2.14527729, -0.3113748 , -2.19110157),
# ...

# %% [markdown]
# ## K2SFF

# %%
k2sff = cr.K2sff(epicid=epicid, campaign=campaign, verbose=False)
lc = k2sff.lc_k2sff
lc.scatter()

# %%
k2sff.k2sff_recarray
# Out:
# FITS_rec([(2988.52108539, 1.21578223, 1.23173569, 2.87778661, 0, 140924),
#           (2988.54151747, 1.21534058, 1.23017519, 3.08852437, 0, 140925),
#           (2988.56194964, 1.21658632, 1.23378576, 3.3179234 , 0, 140926),
#           ...,
#           (3068.08225114, 0.94858456, 0.99443798, 1.98365319, 0, 144818),
#           (3068.10268294, 0.97001234, 1.02202202, 1.69382025, 0, 144819),
#           (3068.12311473, 1.04360718, 1.08023539, 1.33249699, 0, 144820)],
#          dtype=(numpy.record, [('T', '>f8'), ('FRAW', '>f8'), ('FCOR', '>f8'), ('ARCLENGTH', '>f8'), ('MOVING', '>i2'), ('CADENCENO', '>i4')]))

# %% [markdown]
# ## compare EVEREST and K2SFF

# %%
epicid=247047380
fig = cr.plot_everest_k2sff_comparison(epicid, campaign='all')
# Out:
# EVEREST lc cdpp:
# C13: 8278.03
# K2SFF lc cdpp:
# C13: 8278.03

# %% [markdown]
# ## Quick look

# %% [raw]
# fig = cr.make_kql(toiid=837);
