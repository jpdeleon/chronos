# %% [markdown]
# <a href="https://colab.research.google.com/github/jpdeleon/chronos/blob/master/notebooks/examples-interactive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install git+https://github.com/jpdeleon/chronos.git@master

# %% [markdown]
# # Interactive plot

# %%
import altair as alt
alt.renderers.enable('notebook')

import chronos as cr

chart = cr.plot_interactive(thin=10, min_parallax=1.5)
chart
# Out:
# import altair; altair.notebook()

# %%
chart.save('chart.html')
