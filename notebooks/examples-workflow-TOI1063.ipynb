# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as pl
import matplotlib
matplotlib.rcParams['font.size'] = 12

import chronos as cr
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: True
# 	Port: 443
# 	SSL Port: 443
# WARNING:root:Emcee3 not imported; be advised.

# %%
#initialize star properties
toiid = 1063
star = cr.Star(toiid=toiid)
# Out:
# Target: TOI 1063

# %% [markdown]
# # literature data

# %%
star.toi_params.head()
# Out:
# TIC ID           406976746
# TOI                1063.01
# Previous CTOI          NaN
# Master                   1
# SG1A                     4
# Name: 1063.01, dtype: object

# %%
tic_params = star.query_tic_catalog(return_nearest_xmatch=True)
tic_params.head()
# Out:
# Querying TIC catalog for ra,dec=(230.555 -83.0562) within 3.0 arcsec.
# ID       406976746
# ra         230.559
# dec       -83.0562
# pmRA      -89.1248
# pmDEC     -9.59984
# Name: 0, dtype: object

# %%
tic_params.plx
# Out:
# 16.3323

# %%
gaia_params = star.query_gaia_dr2_catalog(return_nearest_xmatch=True)
gaia_params.head()
# Out:
# Querying Gaia DR2 catalog for ra,dec=(230.555 -83.0562) within 3.0 arcsec.
# solution_id              1635721458409799680
# designation     Gaia DR2 5771517717394679424
# source_id                5771517717394679424
# random_index                       544087866
# ref_epoch                             2015.5
# Name: 0, dtype: object

# %%
gaia_params.parallax
# Out:
# 16.332310962617218

# %%
vizier_tables = star.query_vizier()
# Out:
# Searching Vizier: (230.555 -83.0562) with radius=3.0 arcsec
# No result from Vizier
# 48 tables found.
# {'B/denis/denis': 'DENIS output',
#  'I/193/ppm2': 'Catalogue as an easily readable table',
#  'I/195/catalog': 'The FOCAT-S catalogue',
#  'I/239/tyc_main': 'The main part of Tycho Catalogue',
#  'I/246/act': 'Full ACT catalog, originally split into 48 files, each 30min '
#               'wide',
#  'I/250/catalog': 'The TRC catalogue',
#  'I/252/out': 'The Full Catalogue',
#  'I/259/tyc2': '*The Tycho-2 main catalogue',
#  'I/271/out': 'The Full GSC2.2.1 Catalogue (455851237 objects)',
#  'I/280B/ascc': 'ASCC-2.5 V3: All-sky Compiled Catalogue of 2.5 million stars, '
#                 '3rd version',
#  'I/284/out': 'The Whole-Sky USNO-B1.0 Catalog of 1,045,913,669 sources',
#  'I/289/out': 'The Second U.S. Naval Observatory CCD Astrograph Catalog',
#  'I/297/out': 'The NOMAD-1 Catalog',
#  'I/305/out': 'records of GSC2.3.2 (near 0+0)',
#  'I/312/sample': 'The PPMX Catalog (Position and Proper Motions eXtended)',
#  'I/317/sample': 'Example of formatted output',
#  'I/319/xpm': 'formatted catalog (on a total of 313,610,083 sources)',
#  'I/320/spm4': 'SPM4 output (out of 103319647 stars)',
#  'I/322A/out': 'Fourth U.S. Naval Observatory CCD Astrograph Catalog',
#  'I/324/igsl3': 'the IGSL3 data release',
#  'I/337/gaia': 'GaiaSource data',
#  'I/337/tgas': 'TGAS: Subset of GaiaSource comprising those stars in the '
#                'Hipparcos and Tycho-2 Catalogues for which a full 5-parameter '
#                'astrometric solution has been possible in Gaia Data Release '
#                '(TgasSource)',
#  'I/337/tgasptyc': 'TGAS supplement with BT and VT magnitudes',
#  'I/339/hsoy': 'The HSOY catalogue (583001653 sources)',
#  'I/340/ucac5': 'UCAC5 catalog (107,758,513 sources)',
#  'I/345/gaia2': 'GaiaSource DR2 data',
#  'I/347/gaia2dis': 'Estimating distances from parallaxes (1331909727 sources)',
#  'I/348/catalog': 'Catalog',
#  'I/349/starhorse': 'Starhorse catalog',
#  'II/246/out': '2MASS Point Source Catalogue, output (on a total of '
#                '470,992,970 sources)',
#  'II/311/wise': 'the WISE All-Sky release (among 563,921,584 sources)',
#  'II/328/allwise': '*the AllWISE data release (among 747,634,026 sources)',
#  'II/336/apass9': 'The APASS catalog',
#  'II/354/tgasext': 'E(J-Ks), E(B-V), Rv and Av for Gaia DR1 TGAS stars',
#  'II/358/smss': 'SkyMapper DR1.1',
#  'IV/38/tic': 'Transiting Exoplanet Survey Satellite (TESS) Input Catalog - '
#               'v8.0 (TIC-8), outpout (on a total of 1,727,987,580 sources)',
#  'J/AJ/154/259/table6': 'Fundamental Parameters of 1600080 Tycho-2 Stars',
#  'J/AJ/156/102/table9': 'Candidate Target List (CTL) provided via the '
#                         'Filtergraph data visualization portal service',
#  'J/AJ/158/93/table2': 'Results of our regression in Gaia DR2 (Cat. I/345)',
#  'J/ApJ/833/119/distall': 'Distances and uncertainties of all TGAS sources, no '
#                           'systematics uncertainties included '
#                           '(tgas_dist_all_v01)',
#  'J/ApJ/833/119/distallw': 'Distances and uncertainties of all TGAS sources, '
#                            'systematics uncertainties of 0.3mas included '
#                            '(tgas_dist_all_withsys_v01.csv)',
#  'J/MNRAS/463/4210/ucac4rpm': 'UCAC4-RPM catalog v1.0',
#  'J/MNRAS/471/770/table1': 'Tycho-Gaia astrometric solution',
#  'J/PASP/120/1128/catalog': 'Catalog of griz magnitudes for Tycho-2 stars with '
#                             'B_T_<13mag and V_T_<12mag',
#  'V/136/tycall': 'Photometry and derived parameters for all Tycho 2 stars, '
#                  'including giants',
#  'V/136/tycdwarf': 'Photometry and derived parameters for dwarfs',
#  'VI/135/table15': '[Tycho2Fit.dat] Tycho2 catalog fit',
#  'VI/145/attitude': 'Gaia Attitude Star Catalog (ASC)'}

# %%
star.query_vizier_param("plx")
# Out:
# Found 1 references with plx
# {'J/AJ/156/102/table9': 16.5658}

# %%
simbad_table = star.query_simbad()
simbad_table
# Out:
# Searching MAST for (<SkyCoord (ICRS): (ra, dec, distance) in (deg, deg, pc)
#     (230.5555, -83.05621389, 61.22832233)>) with radius=3.0 arcsec
# No result from Simbad

# %%
mast_table = star.query_mast()
mast_table.tail(3)
# Out:
# Searching MAST for (230.555 -83.0562) with radius=3.0 arcsec
# Available data: ['TESS/TESS', 'SPITZER_SHA/IRAC2', 'SPITZER_SHA/IRAC1', 'HLSP/TESS', 'GALEX/NUV'] in ['Optical', 'Infrared', 'UV']
#    intentType obs_collection provenance_name instrument_name project filters  \
# 11    science           HLSP         ELEANOR      Photometer    TESS    TESS
# 12    science           HLSP         ELEANOR      Photometer    TESS    TESS
# 13    science          GALEX             AIS           GALEX     AIS     NUV
#
#    wavelength_region                       target_name target_classification  \
# 11           Optical  postcard-s0013-3-2-cal-1686-1456                   NaN
# 12           Optical  postcard-s0013-3-2-cal-1686-1510                   NaN
# 13                UV                      AIS_450_1_86                   NaN
#
#                                                obs_id  ...  proposal_type  \
# 11  hlsp_eleanor_tess_ffi_postcard-s0013-3-2-cal-1...  ...            NaN
# 12  hlsp_eleanor_tess_ffi_postcard-s0013-3-2-cal-1...  ...            NaN
# 13                                6386748815268904960  ...            AIS
#
#     sequence_number                                           s_region  \
# 11             13.0  POLYGON ICRS 234.55591100 -83.00844900 230.867...
# 12             13.0  POLYGON ICRS 232.67644400 -83.21994800 228.753...
# 13              NaN        CIRCLE ICRS 230.72218678 -82.94844810 0.625
#
#                                               jpegURL  \
# 11                                                NaN
# 12                                                NaN
# 13  http://galex.stsci.edu/data/GR6/pipe/02-vsn/50...
#
#                                               dataURL  dataRights  mtFlag  \
# 11  mast:HLSP/eleanor/postcards/s0013/3-2/hlsp_ele...      PUBLIC   False
# 12  mast:HLSP/eleanor/postcards/s0013/3-2/hlsp_ele...      PUBLIC   False
# 13  http://galex.stsci.edu/data/GR6/pipe/02-vsn/50...      PUBLIC     NaN
#
#     srcDen        obsid  distance
# 11     NaN  18003901619       0.0
# 12     NaN  18003903265       0.0
# 13  5885.0   1000041158       0.0
#
# [3 rows x 33 columns]

# %%
harps_rv_table = star.query_harps_rv()
harps_rv_table
# Out:
# Loaded: /home/jp/github/research/project/chronos/chronos/../data/HARPS_RVBank_table.csv
#
# Nearest HARPS obj is
# GJ9536: ra,dec=(16:10:15.0268,-84:13:53.813) @ d=106.10 arcmin

# %%
eso_table = star.query_eso()
eso_table
# Out:
# Searching ESO: (230.555 -83.0562) with diameter=3.0 arcsec
# No results from ESO

# %%
specs_obs_table = star.query_specs_from_tfop()
specs_obs_table
# Out:
# Saved: /home/jp/github/research/project/chronos/chronos/../data/tfop_sg2_spec_table.csv
# There are 5 spectra in https://exofop.ipac.caltech.edu/tess/target.php?id=406976746
#          TIC ID  TIC  TOI       Telescope Instrument  Spectral resolution  \
# 2974  406976746  NaN  NaN       LCO (1 m)       NRES              53000.0
# 2975  406976746  NaN  NaN  SMARTS (1.5 m)     CHIRON              80000.0
# 2976  406976746  NaN  NaN  SMARTS (1.5 m)     CHIRON              80000.0
# 2977  406976746  NaN  NaN       LCO (1 m)       NRES              53000.0
# 2978  406976746  NaN  NaN       LCO (1 m)       NRES              53000.0
#
#          Wavelength coverage  SNR/resolution  SNR wavelength  \
# 2974           380 to 860 nm           41.00          550 nm
# 2975  4500 to 8900 Angstroms           44.50  5500 angstroms
# 2976  4500 to 8900 Angstroms           46.70  5500 angstroms
# 2977           380 to 860 nm           41.01          550 nm
# 2978           380 to 860 nm           34.16          550 nm
#
#      Appropriate to PRV             Obs date   User   Group   Tag Notes
# 2974                  N  2019-08-27 18:04:02  rabus  tfopwg  6909  NRES
# 2975                  N           2019-09-07  quinn  tfopwg  5700   NaN
# 2976                  N           2019-09-11  quinn  tfopwg  5701   NaN
# 2977                  N  2019-08-23 18:40:53  rabus  tfopwg  6893  NRES
# 2978                  N  2019-08-25 18:21:52  rabus  tfopwg  6900  NRES

# %% [markdown]
# # stellar characterization

# %%
star.query_vizier_param("Teff")
# Out:
# Found 6 references with Teff
# {'I/345/gaia2': 5300.0,
#  'V/136/tycall': 5232.0,
#  'V/136/tycdwarf': 5232.0,
#  'J/AJ/154/259/table6': 5287.67,
#  'J/AJ/158/93/table2': 5171,
#  'J/MNRAS/471/770/table1': 5231}

# %%
#from tic and tycho-gaia
star.query_vizier_param("logg")
# Out:
# Found 2 references with logg
# {'J/AJ/156/102/table9': 4.61783, 'J/MNRAS/471/770/table1': 4.555}

# %%
star.query_vizier_param("met")
# Out:
# Found 0 references with met
# {}

# %%
star.tic_params.MH, star.tic_params.e_MH
# Out:
# (nan, nan)

# %%
star.get_iso_params(teff=(5200,100),
                    logg=(4.6,0.05),
                    #feh=(,),
                    add_jhk=False
                    )
# Out:
# Gaia and TIC catalog cross-match succeeded.
# {'teff': [5200.0, 100.0],
#  'G': [9.588498, 0.01],
#  'bp': [10.0314417, 0.01],
#  'rp': [9.027062, 0.01],
#  'parallax': [16.332310962617218, 0.1035314124863975],
#  'logg': [4.6, 0.05]}

# %%
#note that adding stellar rotation period would improve age estimate
sd = star.run_stardate()
# Out:
# Input parameters:
# {'Av': [0.34590287134051323, 0.01],
#  'G': [9.588498, 0.01],
#  'bp': [10.0314417, 0.01],
#  'logg': [4.6, 0.05],
#  'parallax': [16.332310962617218, 0.1035314124863975],
#  'rp': [9.027062, 0.01],
#  'teff': [5200.0, 100.0]}
# Init isochrones parameters:
# {'Av': 0.0045,
#  'EEP': 329.58,
#  '[Fe/H]': -0.0478,
#  'ln(Distance)': 5.560681631015528,
#  'log10(Age [yr])': 9.5596}
# 100%|██████████| 10000/10000 [01:19<00:00, 125.55it/s]
# nsteps 10000 burnin 0

# %%
fig = star.plot_flatchain()

# %%
fig = star.plot_corner()

# %% [markdown]
# # lightcurve analysis

# %% [markdown]
# ## cdips lc

# %%
star.cdips = cr.CDIPS(toiid=star.toiid)
# Out:
# Target: TOI 1063
# Available sectors: [12 13]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-39ecf71e6733> in <module>
# ----> 1 star.cdips = cr.CDIPS(toiid=star.toiid)
#
# ~/github/research/project/chronos/chronos/cdips.py in __init__(self, sector, cam, ccd, name, toiid, ticid, epicid, gaiaDR2id, ra_deg, dec_deg, quality_bitmask, search_radius, lctype, aper_idx, mission, verbose, clobber)
#     122                 if sum(idx) == 0:
#     123                     msg = f"CDIPS lc is currently available for sectors={CDIPS_SECTORS}\n"
# --> 124                     raise ValueError(msg)
#     125                 if sum(idx) == 1:
#     126                     self.sector = self.all_sectors[idx][0] #get first available
#
# ValueError: CDIPS lc is currently available for sectors=[6, 7, 8, 9, 10, 11]

# %% [raw]
# star.cdips.lc.plot()

# %% [raw]
# #transit duration in ncadences
# t14_ncadences = int(round(star.cdips.toi_duration*cr.u.hour.to(cr.u.minute)/30))
# t14_ncadences

# %% [raw]
# lc_raw = star.cdips.lc
# tmask = cr.get_transit_mask(lc_raw,
#                             period=star.toi_period,
#                             epoch=star.toi_epoch-cr.TESS_TIME_OFFSET,
#                             duration_hours=star.toi_duration)
# lc = lc_raw[~tmask]
# ax = lc_raw.scatter(label='raw')
# lc_raw[tmask].scatter(ax=ax, label='transits')
# flat, trend = lc.flatten(window_length=1+t14_ncadences*3, return_trend=True)
# trend.plot(ax=ax, c='r', lw=1, label='trend')

# %% [raw]
# ax = flat.fold(period=star.toi_period, t0=star.toi_epoch).scatter()
# ax.set_xlim(-0.05,0.05)

# %% [markdown]
# ## long cadence

# %% [raw]
# star.lc = cr.LongCadence(toiid=837)

# %% [markdown]
# ## short cadence

# %%
#initialize lightcurve functionalities
star.sc = cr.ShortCadence(toiid=1063)
# Out:
# Target: TOI 1063
# Available sectors: [12 13]
# Using sector=12.

# %%
all_sectors = star.sc.all_sectors
all_sectors
# Out:
# array([12, 13])

# %%
lc1 = star.sc.get_lc(sector=all_sectors[0])
tmask1 = cr.get_transit_mask(lc1, 
                            period=star.sc.toi_period,
                            epoch=star.sc.toi_epoch-cr.TESS_TIME_OFFSET,
                            duration_hours=star.sc.toi_duration)
ax=lc1.scatter(label='raw')
lc1[tmask1].scatter(label='transits', ax=ax)
# Out:
# Searching lightcurvefile for TIC 406976746 (sector 12)
# Found 1 lightcurves

# %%
lc2 = star.sc.get_lc(sector=all_sectors[1])
tmask2 = cr.get_transit_mask(lc2, 
                            period=star.sc.toi_period,
                            epoch=star.sc.toi_epoch-cr.TESS_TIME_OFFSET,
                            duration_hours=star.sc.toi_duration)
ax=lc2.scatter(label='raw')
lc2[tmask2].scatter(label='transits', ax=ax)
# Out:
# Searching lightcurvefile for TIC 406976746 (sector 13)
# Found 1 lightcurves

# %% [markdown]
# ### merging multi-sector lc

# %%
#with masked transits
lc = lc1[~tmask1].append(lc2[~tmask2])
#without
lc_raw = lc1.append(lc2)

# %%
lc.detrend = lambda : cr.detrend(lc)
ax = lc.scatter(label='orig')
#lc.detrend().scatter(label='detrended', ax=ax)

# %% [markdown]
# ### rotation period using Lomb-Scargle periodogram

# %%
prot, prot_err = cr.get_rotation_period(lc.time, lc.flux)
prot, prot_err
# Out:
# P=7.87+/-0.39 d
# (7.870666524590165, 0.3873111148653231)

# %%
fig = cr.plot_rotation_period(lc.time, lc.flux)
# Out:
# P=7.87+/-0.39 d

# %% [markdown]
# ### rotation period using Generalized Lomb-Scargle periodogram

# %%
data = lc.time, lc.flux, lc.flux_err
gls = cr.Gls(data, verbose=True)
# Out:
# Generalized LS - statistical output
# -----------------------------------
# Number of input points:      37782
# Weighted mean of dataset:   0.999203
# Weighted rms of dataset:    0.006294
# Time base:                  57.399697
# Number of frequency points:    573
#
# Maximum power p [ZK]: 0.760216
# RMS of residuals:     0.003082
#   Mean weighted internal error:  0.000688
# Best sine frequency:  0.127178 +/- 0.000038
# Best sine period:     7.862972 +/- 0.002370
# Amplitude:            0.007862 +/- 0.000022
# -----------------------------------

# %%
fig = gls.plot()

# %% [markdown]
# ### age estimates

# %%
#using iso+gyro
sd = star.run_stardate(prot=(prot,prot_err))
# Out:
# Input parameters:
# {'Av': [0.34590287134051323, 0.01],
#  'G': [9.588498, 0.01],
#  'bp': [10.0314417, 0.01],
#  'logg': [4.6, 0.05],
#  'parallax': [16.332310962617218, 0.1035314124863975],
#  'rp': [9.027062, 0.01],
#  'teff': [5200.0, 100.0]}
# Init isochrones parameters:
# {'Av': 0.0045,
#  'EEP': 329.58,
#  '[Fe/H]': -0.0478,
#  'ln(Distance)': 5.560681631015528,
#  'log10(Age [yr])': 9.5596}
# 100%|██████████| 10000/10000 [02:49<00:00, 59.15it/s]
# nsteps 10000 burnin 0

# %%
#get age results
age,age_plus,age_minus,samples = star.get_age(method='isochrones', 
                                              prot=(prot,prot_err), 
                                              return_samples=True,
                                              plot=True)
# Out:
# Estimating age from isochrones
#
# iso+gyro age = 465.87 + 1074.20 - 108.10 Myr

# %%
#get age results
age,age_plus,age_minus,samples = star.get_age(method='prot', 
                                              prot=(prot,prot_err), 
                                              return_samples=True,
                                              plot=True)
# Out:
# Estimating age from rotation period
#
# Gaia and TIC catalog cross-match succeeded.
# Estimating age using gyrochronology
#
# gyro age = 474.41 + 87.29 - 52.93 Myr using rotation period 7.87+/-0.39d

# %%
#get age results
age,age_plus,age_minus,samples = star.get_age(method='amp', 
                                              lc=lc,
                                              prot=(prot,prot_err),
                                              return_samples=True,
                                              plot=True)
# Out:
# Estimating age using rotation amplitude
#
# More than 39.81% of derived ages is outside (0.01,4) Gyr
# gyro age = 394.84 + 868.90 - 327.44 Myr using rotation amplitude 1.68+/-0.29%
